# %% [markdown]
# # Iris Project
# In this notebook we will explore  the iris dataset
#
# First let's import numpy ,pandas, seaborn,matplotlib. The library that we will use in this notebook

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Now we can charge the iris dataset

# %%
df=pd.read_csv("data/iris_dataset.csv")
df.head()
# Out:
#    id  sepal_length  sepal_width  petal_length  petal_width species
# 0   1      5.138728     3.470118      1.441015     1.094873  setosa
# 1   2      4.849873     3.034931      1.414931     0.968687  setosa
# 2   3      4.715843     3.239083      1.295309     1.006643  setosa
# 3   4      4.603747          NaN      1.480616     1.002344  setosa
# 4   5      4.988744     3.645049      1.417527     1.122947  setosa

# %% [markdown]
# # Iris data from Seaborn
# Let's use seaborn to visualize the data

# %%
df.describe()
# Out:
#                id  sepal_length  sepal_width  petal_length  petal_width
# count  150.000000    150.000000   147.000000    150.000000   149.000000
# mean    75.500000      5.837808     3.052765      3.754958     1.961671
# std     43.445368      0.829649     0.441390      1.764346     0.730604
# min      1.000000      4.270281     2.025099      1.012829     0.814850
# 25%     38.250000      5.112737     2.753251      1.551973     1.180657
# 50%     75.500000      5.765678     3.011189      4.342197     2.038432
# 75%    112.750000      6.411706     3.330501      5.078362     2.563017
# max    150.000000      7.903810     4.394665      6.892382     3.391172

# %%
sns.pairplot(df,hue="species")

# %% [markdown]
# Let's include the date by species

# %%
df.groupby("species").count()
# Out:
#             id  sepal_length  sepal_width  petal_length  petal_width
# species
# setosa      50            50           49            50           50
# versicolor  50            50           49            50           49
# virginica   50            50           49            50           50

# %%
df=df.dropna()

# %%
df
# Out:
#       id  sepal_length  sepal_width  petal_length  petal_width    species
# 0      1      5.138728     3.470118      1.441015     1.094873     setosa
# 1      2      4.849873     3.034931      1.414931     0.968687     setosa
# 2      3      4.715843     3.239083      1.295309     1.006643     setosa
# 4      5      4.988744     3.645049      1.417527     1.122947     setosa
# 5      6      5.430821     3.884073      1.699534     1.370708     setosa
# ..   ...           ...          ...           ...          ...        ...
# 145  146      6.664208     2.994751      5.219754     3.061857  virginica
# 146  147      6.319889     2.453381      5.035004     2.536681  virginica
# 147  148      6.488279     2.989227      5.203232     2.749461  virginica
# 148  149      6.228777     3.371570      5.416274     3.153742  virginica
# 149  150      5.879011     3.048696      5.059241     2.535001  virginica
#
# [146 rows x 6 columns]

# %%
df.groupby('species').count()
# Out:
#             id  sepal_length  sepal_width  petal_length  petal_width
# species
# setosa      49            49           49            49           49
# versicolor  48            48           48            48           48
# virginica   49            49           49            49           49

# %%
sns.distplot(df["sepal_length"],hist=False)

# %% [markdown]
# # Using violon plot

# %%
plt.figure(figsize=(30,10))

# %%
plt.subplot(2,2,1)
sns.violinplot(x="species",y="sepal_length",data=df)
plt.subplot(2,2,2)
sns.violinplot(x="species",y="sepal_width",data=df)
plt.subplot(2,2,3)
sns.boxplot(x="species",y="petal_length",data=df)
plt.subplot(2,2,4)
sns.boxplot(x="species",y="petal_width",data=df)
