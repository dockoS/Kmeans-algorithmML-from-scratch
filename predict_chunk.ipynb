# %% [markdown]
# # In this notebook we want to predict if a user will quit the expresso network or not

# %% [markdown]
# First let's charge the datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
data_path='data'
train=pd.read_csv('%s/Train.csv'%data_path)
test=pd.read_csv('%s/Test.csv'%data_path)
variable_definitions=pd.read_csv('%s/VariableDefinitions.csv'%data_path)

train.shape
# Out:
# (2154048, 19)

# %%
variable_definitions
# Out:
#    Variable Definitions                                         Unnamed: 1  \
# 0                   NaN                                             French
# 1                   NaN  Le dataset churn comprend 19 variables dont 15...
# 2               user_id                                                NaN
# 3                REGION                       la localité de chaque client
# 4                TENURE                            la durée dans le reseau
# 5               MONTANT                                montant de recharge
# 6        FREQUENCE_RECH   nombre de fois que le client a fait une recharge
# 7               REVENUE                    revenu mensuel de chaque client
# 8          ARPU_SEGMENT                              revenu sur 90 jours/3
# 9             FREQUENCE         nombre de fois que client à fait un revenu
# 10          DATA_VOLUME                               nombre de connexions
# 11               ON_NET                               appel inter expresso
# 12               ORANGE                                  appel vers orange
# 13                 TIGO                                    appel vers Tigo
# 14                ZONE1                               appel vers les zone1
# 15                ZONE2                               appel vers les zone2
# 16                  MRG                          un client qui fait du vas
# 17           REGULARITY  nombre de fois que le client est actif pendant...
# 18             TOP_PACK                          les pack les plus activés
# 19        FREQ_TOP_PACK  nombre de fois que le client a activé les pack...
# 20                CHURN                        variable à predire - Target
#
#                                            Unnamed: 2
# 0                                             English
# 1   The churn dataset includes 19 variables includ...
# 2                                                 NaN
# 3                         the location of each client
# 4                             duration in the network
# 5                                       top-up amount
# 6               number of times the customer refilled
# 7                       monthly income of each client
# 8                             income over 90 days / 3
# 9       number of times the client has made an income
# 10                              number of connections
# 11                                inter expresso call
# 12                                     call to orange
# 13                                       call to Tigo
# 14                                     call to zones1
# 15                                     call to zones2
# 16                              a client who is going
# 17   number of times the client is active for 90 days
# 18                              the most active packs
# 19  number of times the client has activated the t...
# 20                       variable to predict - Target

# %%
train["MRG"].unique()
# Out:
# array(['NO'], dtype=object)

# %% [markdown]
# MRG have a constant value donc let's drop in the dataset

# %%
train=train.drop("MRG",axis=1)
test=test.drop("MRG",axis=1)

# %%
train.head(5)
# Out:
#                                     user_id  REGION         TENURE  MONTANT  \
# 0  00000bfd7d50f01092811bc0c8d7b0d6fe7c3596  FATICK   K > 24 month   4250.0
# 1  00000cb4a5d760de88fecb38e2f71b7bec52e834     NaN  I 18-21 month      NaN
# 2  00001654a9d9f96303d9969d0a4a851714a4bb57     NaN   K > 24 month   3600.0
# 3  00001dd6fa45f7ba044bd5d84937be464ce78ac2   DAKAR   K > 24 month  13500.0
# 4  000028d9e13a595abe061f9b58f3d76ab907850f   DAKAR   K > 24 month   1000.0
#
#    FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  DATA_VOLUME  ON_NET  \
# 0            15.0   4251.0        1417.0       17.0          4.0   388.0
# 1             NaN      NaN           NaN        NaN          NaN     NaN
# 2             2.0   1020.0         340.0        2.0          NaN    90.0
# 3            15.0  13502.0        4501.0       18.0      43804.0    41.0
# 4             1.0    985.0         328.0        1.0          NaN    39.0
#
#    ORANGE  TIGO  ZONE1  ZONE2  REGULARITY                        TOP_PACK  \
# 0    46.0   1.0    1.0    2.0          54  On net 200F=Unlimited _call24H
# 1     NaN   NaN    NaN    NaN           4                             NaN
# 2    46.0   7.0    NaN    NaN          17         On-net 1000F=10MilF;10d
# 3   102.0   2.0    NaN    NaN          62               Data:1000F=5GB,7d
# 4    24.0   NaN    NaN    NaN          11     Mixt 250F=Unlimited_call24H
#
#    FREQ_TOP_PACK  CHURN
# 0            8.0      0
# 1            NaN      1
# 2            1.0      0
# 3           11.0      0
# 4            2.0      0

# %% [markdown]
# checking the number of null value of each feature

# %%
train.isnull().sum(axis=0).sort_values()
# Out:
# user_id                 0
# REGULARITY              0
# CHURN                   0
# TENURE                  0
# REVENUE            726048
# ARPU_SEGMENT       726048
# FREQUENCE          726048
# MONTANT            756739
# FREQUENCE_RECH     756739
# ON_NET             786675
# REGION             849299
# ORANGE             895248
# FREQ_TOP_PACK      902594
# TOP_PACK           902594
# DATA_VOLUME       1060433
# TIGO              1290016
# ZONE1             1984327
# ZONE2             2017224
# dtype: int64

# %% [markdown]
# ## Feature generation

# %%
train["FREQUENCE_BY_FREQUENCE_RECH"]=train["FREQUENCE"]/train["FREQUENCE_RECH"]
test["FREQUENCE_BY_FREQUENCE_RECH"]=test["FREQUENCE"]/test["FREQUENCE_RECH"]

# %%
train.head(5)
# Out:
#                                     user_id  REGION         TENURE  MONTANT  \
# 0  00000bfd7d50f01092811bc0c8d7b0d6fe7c3596  FATICK   K > 24 month   4250.0
# 1  00000cb4a5d760de88fecb38e2f71b7bec52e834     NaN  I 18-21 month      NaN
# 2  00001654a9d9f96303d9969d0a4a851714a4bb57     NaN   K > 24 month   3600.0
# 3  00001dd6fa45f7ba044bd5d84937be464ce78ac2   DAKAR   K > 24 month  13500.0
# 4  000028d9e13a595abe061f9b58f3d76ab907850f   DAKAR   K > 24 month   1000.0
#
#    FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  DATA_VOLUME  ON_NET  \
# 0            15.0   4251.0        1417.0       17.0          4.0   388.0
# 1             NaN      NaN           NaN        NaN          NaN     NaN
# 2             2.0   1020.0         340.0        2.0          NaN    90.0
# 3            15.0  13502.0        4501.0       18.0      43804.0    41.0
# 4             1.0    985.0         328.0        1.0          NaN    39.0
#
#    ORANGE  TIGO  ZONE1  ZONE2  REGULARITY                        TOP_PACK  \
# 0    46.0   1.0    1.0    2.0          54  On net 200F=Unlimited _call24H
# 1     NaN   NaN    NaN    NaN           4                             NaN
# 2    46.0   7.0    NaN    NaN          17         On-net 1000F=10MilF;10d
# 3   102.0   2.0    NaN    NaN          62               Data:1000F=5GB,7d
# 4    24.0   NaN    NaN    NaN          11     Mixt 250F=Unlimited_call24H
#
#    FREQ_TOP_PACK  CHURN  FREQUENCE_BY_FREQUENCE_RECH
# 0            8.0      0                     1.133333
# 1            NaN      1                          NaN
# 2            1.0      0                     1.000000
# 3           11.0      0                     1.200000
# 4            2.0      0                     1.000000

# %%
train["TOP_PACK"].unique()
# Out:
# array(['On net 200F=Unlimited _call24H', nan, 'On-net 1000F=10MilF;10d',
#        'Data:1000F=5GB,7d', 'Mixt 250F=Unlimited_call24H',
#        'MIXT:500F= 2500F on net _2500F off net;2d',
#        'All-net 500F=2000F;5d', 'On-net 500F_FNF;3d',
#        'Data: 100 F=40MB,24H', 'MIXT: 200mnoff net _unl on net _5Go;30d',
#        'Jokko_Daily', 'Data: 200 F=100MB,24H', 'Data:490F=1GB,7d',
#        'Twter_U2opia_Daily', 'On-net 500=4000,10d', 'Data:1000F=2GB,30d',
#        'IVR Echat_Daily_50F', 'Pilot_Youth4_490',
#        'All-net 500F =2000F_AllNet_Unlimited', 'Twter_U2opia_Weekly',
#        'Data:200F=Unlimited,24H', 'On-net 200F=60mn;1d',
#        'All-net 600F= 3000F ;5d', 'Pilot_Youth1_290',
#        'All-net 1000F=(3000F On+3000F Off);5d', 'VAS(IVR_Radio_Daily)',
#        'Data:3000F=10GB,30d', 'All-net 1000=5000;5d',
#        'Twter_U2opia_Monthly', 'MIXT: 390F=04HOn-net_400SMS_400 Mo;4h\t',
#        'FNF2 ( JAPPANTE)', 'Yewouleen_PKG', 'Data:150F=SPPackage1,24H',
#        'WIFI_Family_2MBPS', 'Data:500F=2GB,24H', 'MROMO_TIMWES_RENEW',
#        'New_YAKALMA_4_ALL', 'Data:1500F=3GB,30D',
#        'All-net 500F=4000F ; 5d', 'Jokko_promo', 'All-net 300=600;2d',
#        'Data:300F=100MB,2d',
#        'MIXT: 590F=02H_On-net_200SMS_200 Mo;24h\t\t',
#        'All-net 500F=1250F_AllNet_1250_Onnet;48h', 'Facebook_MIX_2D',
#        '500=Unlimited3Day', 'On net 200F= 3000F_10Mo ;24H',
#        '200=Unlimited1Day', 'YMGX 100=1 hour FNF, 24H/1 month',
#        'SUPERMAGIK_5000', 'Data:DailyCycle_Pilot_1.5GB', 'Staff_CPE_Rent',
#        'MIXT:1000F=4250 Off net _ 4250F On net _100Mo; 5d',
#        'Data:50F=30MB_24H', 'Data:700F=SPPackage1,7d',
#        'Data: 490F=Night,00H-08H', 'Data:700F=1.5GB,7d',
#        'Data:1500F=SPPackage1,30d', 'Data:30Go_V 30_Days',
#        'MROMO_TIMWES_OneDAY', 'On-net 300F=1800F;3d',
#        'All-net 5000= 20000off+20000on;30d', 'WIFI_ Family _4MBPS',
#        'CVM_on-net bundle 500=5000', 'Internat: 1000F_Zone_3;24h\t\t',
#        'DataPack_Incoming', 'Jokko_Monthly', 'EVC_500=2000F',
#        'On-net 2000f_One_Month_100H; 30d',
#        'MIXT:10000F=10hAllnet_3Go_1h_Zone3;30d\t\t', 'EVC_Jokko_Weekly',
#        '200F=10mnOnNetValid1H', 'IVR Echat_Weekly_200F',
#        'WIFI_ Family _10MBPS', 'Internat: 1000F_Zone_1;24H\t\t',
#        'Jokko_Weekly', 'SUPERMAGIK_1000',
#        'MIXT: 500F=75(SMS, ONNET, Mo)_1000FAllNet;24h\t\t',
#        'VAS(IVR_Radio_Monthly)',
#        'MIXT: 5000F=80Konnet_20Koffnet_250Mo;30d\t\t',
#        'Data: 200F=1GB,24H', 'EVC_JOKKO30',
#        'NEW_CLIR_TEMPALLOWED_LIBERTE_MOBILE', 'TelmunCRBT_daily',
#        'FIFA_TS_weekly', 'VAS(IVR_Radio_Weekly)',
#        'Internat: 2000F_Zone_2;24H\t\t', 'APANews_weekly', 'EVC_100Mo',
#        'pack_chinguitel_24h', 'Data_EVC_2Go24H',
#        'Mixt : 500F=2500Fonnet_2500Foffnet ;5d', 'FIFA_TS_daily',
#        'MIXT: 4900F= 10H on net_1,5Go ;30d', 'CVM_200f=400MB',
#        'IVR Echat_Monthly_500F', 'All-net 500= 4000off+4000on;24H',
#        'FNF_Youth_ESN', 'Data:1000F=700MB,7d', '1000=Unlimited7Day',
#        'Incoming_Bonus_woma', 'CVM_100f=200 MB', 'CVM_100F_unlimited',
#        'pilot_offer6', '305155009', 'Postpaid FORFAIT 10H Package',
#        'EVC_1Go', 'GPRS_3000Equal10GPORTAL',
#        'NEW_CLIR_PERMANENT_LIBERTE_MOBILE', 'Data_Mifi_10Go_Monthly',
#        '1500=Unlimited7Day', 'EVC_700Mo', 'CVM_100f=500 onNet',
#        'CVM_On-net 1300f=12500', 'pilot_offer5', 'EVC_4900=12000F',
#        'CVM_On-net 400f=2200F', 'YMGX on-net 100=700F, 24H',
#        'CVM_150F_unlimited', 'EVC_MEGA10000F', 'pilot_offer7',
#        'CVM_500f=2GB', 'SMS Max', '301765007', '150=unlimited pilot auto',
#        'MegaChrono_3000F=12500F TOUS RESEAUX', 'pilot_offer4',
#        'Go-NetPro-4 Go', '200=unlimited pilot auto',
#        'ESN_POSTPAID_CLASSIC_RENT', 'Data_Mifi_10Go',
#        'Data:New-GPRS_PKG_1500F', 'GPRS_BKG_1000F MIFI',
#        'Data:OneTime_Pilot_1.5GB', 'FIFA_TS_monthly',
#        'GPRS_PKG_5GO_ILLIMITE', 'Data_Mifi_20Go', 'APANews_monthly',
#        'NEW_CLIR_TEMPRESTRICTED_LIBERTE_MOBILE', 'GPRS_5Go_7D_PORTAL',
#        'Package3_Monthly'], dtype=object)

# %%
test.head()
# Out:
#                                     user_id REGION         TENURE  MONTANT  \
# 0  00001dbe00e56fc4b1c1b65dda63de2a5ece55f9  THIES   K > 24 month   5000.0
# 1  000055d41c8a62052dd426592e8a4a3342bf565d    NaN  I 18-21 month    300.0
# 2  000081dd3245e6869a4a9c574c7050e7bb84c2c8  DAKAR   K > 24 month   3300.0
# 3  0000b76d2145d9445d9ff6b65c9ebc4196c89337    NaN   K > 24 month      NaN
# 4  0000bae5480628cf8fe51ad84bcb39772fc79224    NaN   K > 24 month      NaN
#
#    FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  DATA_VOLUME  ON_NET  \
# 0             5.0   5000.0        1667.0        5.0          NaN   378.0
# 1             2.0    326.0         109.0        3.0        397.0     NaN
# 2            25.0   3400.0        1133.0       26.0       7150.0     0.0
# 3             NaN      NaN           NaN        NaN          NaN     NaN
# 4             NaN      NaN           NaN        NaN          NaN     NaN
#
#    ORANGE  TIGO  ZONE1  ZONE2  REGULARITY                 TOP_PACK  \
# 0    11.0   5.0    NaN    NaN          42  On-net 1000F=10MilF;10d
# 1     0.0   NaN    NaN    NaN          41     Data: 100 F=40MB,24H
# 2     2.0   5.0    NaN    NaN          57     Data: 100 F=40MB,24H
# 3     NaN   NaN    NaN    NaN           9                      NaN
# 4     NaN   NaN    NaN    NaN          10                      NaN
#
#    FREQ_TOP_PACK  FREQUENCE_BY_FREQUENCE_RECH
# 0            5.0                         1.00
# 1            1.0                         1.50
# 2           22.0                         1.04
# 3            NaN                          NaN
# 4            NaN                          NaN

# %% [markdown]
# for i in range (len(train)):
#     if train.iloc[i]["sum_extra"]!=0:
#         train.iloc[i]["RATIO_ON_NET_BY_EXTRA_NET"]=train.iloc[i]["ON_NET"]/(train.iloc[i]["sum_extra"])
#     else:
#         train.iloc[i]["RATIO_ON_NET_BY_EXTRA_NET"]=train.iloc[i]["ON_NET"]
# for i in range (len(test)):
#     if test.iloc[i]["sum_extra"]!=0:
#         test.iloc[i]["RATIO_ON_NET_BY_EXTRA_NET"]=test.iloc[i]["ON_NET"]/(test.iloc[i]["sum_extra"])
#     else:
#         test.iloc[i]["RATIO_ON_NET_BY_EXTRA_NET"]=test.iloc[i]["ON_NET"]

# %%
train["sum_extra"]=train["ORANGE"]+train["TIGO"]
test["sum_extra"]=test["ORANGE"]+test["TIGO"]

# %%
train["sum_extra"]=train["sum_extra"].map(lambda x : x if x!=0.0 else 0.5)
test["sum_extra"]=test["sum_extra"].map(lambda x : x if x!=0.0 else 0.5)

# %%
train["RATIO_ON_NET_BY_EXTRA_NET"]=train["ON_NET"]/train["sum_extra"] 
test["RATIO_ON_NET_BY_EXTRA_NET"]=test["ON_NET"]/test["sum_extra"]

# %%
train["RATIO_ON_NET_BY_ORANGE"]=train["ON_NET"]/train["ORANGE"].map(lambda x : x if x!=0.0 else 0.5) 
train["RATIO_ON_NET_BY_TIGO"]=train["ON_NET"]/train["TIGO"].map(lambda x : x if x!=0.0 else 0.5) 
test["RATIO_ON_NET_BY_ORANGE"]=test["ON_NET"]/test["ORANGE"].map(lambda x : x if x!=0.0 else 0.5)
test["RATIO_ON_NET_BY_TIGO"]=test["ON_NET"]/test["TIGO"].map(lambda x : x if x!=0.0 else 0.5)

# %%
train["HYPOTHENUS_FREQ_AND_FREQ_RECH"]=np.square(train["FREQUENCE"])+np.square(train["FREQUENCE_RECH"])
test["HYPOTHENUS_FREQ_AND_FREQ_RECH"]=np.square(test["FREQUENCE"])+np.square(test["FREQUENCE_RECH"])

# %%
train["HYPOTHENUS_FREQ_AND_REGULARITY"]=np.square(train["FREQUENCE"])+np.square(train["REGULARITY"])
test["HYPOTHENUS_FREQ_AND_REGULARITY"]=np.square(test["FREQUENCE"])+np.square(test["REGULARITY"])

# %%
#generation of mean of the price of top pack
train["MEAN_PRICE_TOP_PACK"]=train["MONTANT"]/train["FREQ_TOP_PACK"]
test["MEAN_PRICE_TOP_PACK"]=test["MONTANT"]/test["FREQ_TOP_PACK"]

# %%
#generation of the ratio of the mensual revenuby the mean of the price of top pack
train["MENSUAL_BY_MEAN_PRICE_TOP_PACK"]=train["REVENUE"]/train["MEAN_PRICE_TOP_PACK"]
test["MENSUAL_BY_MEAN_PRICE_TOP_PACK"]=test["REVENUE"]/test["MEAN_PRICE_TOP_PACK"]

# %%
len(train.columns)
train.head(5)
# Out:
#                                     user_id  REGION         TENURE  MONTANT  \
# 0  00000bfd7d50f01092811bc0c8d7b0d6fe7c3596  FATICK   K > 24 month   4250.0
# 1  00000cb4a5d760de88fecb38e2f71b7bec52e834     NaN  I 18-21 month      NaN
# 2  00001654a9d9f96303d9969d0a4a851714a4bb57     NaN   K > 24 month   3600.0
# 3  00001dd6fa45f7ba044bd5d84937be464ce78ac2   DAKAR   K > 24 month  13500.0
# 4  000028d9e13a595abe061f9b58f3d76ab907850f   DAKAR   K > 24 month   1000.0
#
#    FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  DATA_VOLUME  ON_NET  ...  \
# 0            15.0   4251.0        1417.0       17.0          4.0   388.0  ...
# 1             NaN      NaN           NaN        NaN          NaN     NaN  ...
# 2             2.0   1020.0         340.0        2.0          NaN    90.0  ...
# 3            15.0  13502.0        4501.0       18.0      43804.0    41.0  ...
# 4             1.0    985.0         328.0        1.0          NaN    39.0  ...
#
#    CHURN  FREQUENCE_BY_FREQUENCE_RECH  sum_extra  RATIO_ON_NET_BY_EXTRA_NET  \
# 0      0                     1.133333       47.0                   8.255319
# 1      1                          NaN        NaN                        NaN
# 2      0                     1.000000       53.0                   1.698113
# 3      0                     1.200000      104.0                   0.394231
# 4      0                     1.000000        NaN                        NaN
#
#    RATIO_ON_NET_BY_ORANGE RATIO_ON_NET_BY_TIGO  HYPOTHENUS_FREQ_AND_FREQ_RECH  \
# 0                8.434783           388.000000                          514.0
# 1                     NaN                  NaN                            NaN
# 2                1.956522            12.857143                            8.0
# 3                0.401961            20.500000                          549.0
# 4                1.625000                  NaN                            2.0
#
#    HYPOTHENUS_FREQ_AND_REGULARITY  MEAN_PRICE_TOP_PACK  \
# 0                          3205.0           531.250000
# 1                             NaN                  NaN
# 2                           293.0          3600.000000
# 3                          4168.0          1227.272727
# 4                           122.0           500.000000
#
#    MENSUAL_BY_MEAN_PRICE_TOP_PACK
# 0                        8.001882
# 1                             NaN
# 2                        0.283333
# 3                       11.001630
# 4                        1.970000
#
# [5 rows x 27 columns]

# %%
#Cleaning the TENURE attribut .We classify the tenure by K,I,J,et
train["TENURE"].unique()
train["TENURE"]=train["TENURE"].map(lambda x:x[0])
test["TENURE"]=test["TENURE"].map(lambda x:x[0])
train["REGION"]=train["REGION"].fillna("UNKNOW")
test["REGION"]=test["REGION"].fillna("UNKNOW")
train["TOP_PACK"]=train["TOP_PACK"].fillna("UNKNOW")
test["TOP_PACK"]=test["TOP_PACK"].fillna("UNKNOW")

# %%
#Let's combine the thre cathegorical variable
cat_cols_combined=["TENURE-REGION","REGION-TOP_PACK","TOP_PACK-TENURE"]
for attribs in cat_cols_combined:
    indexes=attribs.split("-")
    train[indexes[0]+"_"+indexes[1]]=train[indexes[0]]+"_"+train[indexes[1]]
    test[indexes[0]+"_"+indexes[1]]=test[indexes[0]]+"_"+test[indexes[1]]
    
train["TENURE_REGION_TOP_PACK"]=train["TENURE"]+"_"+train["REGION"]+"_"+train["TOP_PACK"]
test["TENURE_REGION_TOP_PACK"]=test["TENURE"]+"_"+test["REGION"]+"_"+test["TOP_PACK"]

# %%
train.head(5)
# Out:
#                                     user_id  REGION TENURE  MONTANT  \
# 0  00000bfd7d50f01092811bc0c8d7b0d6fe7c3596  FATICK      K   4250.0
# 1  00000cb4a5d760de88fecb38e2f71b7bec52e834  UNKNOW      I      NaN
# 2  00001654a9d9f96303d9969d0a4a851714a4bb57  UNKNOW      K   3600.0
# 3  00001dd6fa45f7ba044bd5d84937be464ce78ac2   DAKAR      K  13500.0
# 4  000028d9e13a595abe061f9b58f3d76ab907850f   DAKAR      K   1000.0
#
#    FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  DATA_VOLUME  ON_NET  ...  \
# 0            15.0   4251.0        1417.0       17.0          4.0   388.0  ...
# 1             NaN      NaN           NaN        NaN          NaN     NaN  ...
# 2             2.0   1020.0         340.0        2.0          NaN    90.0  ...
# 3            15.0  13502.0        4501.0       18.0      43804.0    41.0  ...
# 4             1.0    985.0         328.0        1.0          NaN    39.0  ...
#
#    RATIO_ON_NET_BY_ORANGE  RATIO_ON_NET_BY_TIGO  \
# 0                8.434783            388.000000
# 1                     NaN                   NaN
# 2                1.956522             12.857143
# 3                0.401961             20.500000
# 4                1.625000                   NaN
#
#    HYPOTHENUS_FREQ_AND_FREQ_RECH  HYPOTHENUS_FREQ_AND_REGULARITY  \
# 0                          514.0                          3205.0
# 1                            NaN                             NaN
# 2                            8.0                           293.0
# 3                          549.0                          4168.0
# 4                            2.0                           122.0
#
#    MEAN_PRICE_TOP_PACK MENSUAL_BY_MEAN_PRICE_TOP_PACK  TENURE_REGION  \
# 0           531.250000                       8.001882       K_FATICK
# 1                  NaN                            NaN       I_UNKNOW
# 2          3600.000000                       0.283333       K_UNKNOW
# 3          1227.272727                      11.001630        K_DAKAR
# 4           500.000000                       1.970000        K_DAKAR
#
#                          REGION_TOP_PACK                   TOP_PACK_TENURE  \
# 0  FATICK_On net 200F=Unlimited _call24H  On net 200F=Unlimited _call24H_K
# 1                          UNKNOW_UNKNOW                          UNKNOW_I
# 2         UNKNOW_On-net 1000F=10MilF;10d         On-net 1000F=10MilF;10d_K
# 3                DAKAR_Data:1000F=5GB,7d               Data:1000F=5GB,7d_K
# 4      DAKAR_Mixt 250F=Unlimited_call24H     Mixt 250F=Unlimited_call24H_K
#
#                     TENURE_REGION_TOP_PACK
# 0  K_FATICK_On net 200F=Unlimited _call24H
# 1                          I_UNKNOW_UNKNOW
# 2         K_UNKNOW_On-net 1000F=10MilF;10d
# 3                K_DAKAR_Data:1000F=5GB,7d
# 4      K_DAKAR_Mixt 250F=Unlimited_call24H
#
# [5 rows x 31 columns]

# %%
#The train set is very large let's get 800000 samples to train our model
import random
from sklearn.model_selection import train_test_split
random.seed(123)
sample= random.sample(range(0,len(train)), 500000)
train_sample=train.iloc[sample]
train_sample=train_sample.drop("user_id",axis=1)

# %%
train_sample
# Out:
#            REGION TENURE  MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  \
# 219628   DIOURBEL      K   5500.0             9.0   5500.0        1833.0
# 1122719     DAKAR      K   1000.0             1.0   1000.0         333.0
# 365687     UNKNOW      K      NaN             NaN      NaN           NaN
# 1708095   KAOLACK      K      NaN             NaN      NaN           NaN
# 1118007    UNKNOW      K      NaN             NaN      NaN           NaN
# ...           ...    ...      ...             ...      ...           ...
# 2013547    UNKNOW      K      NaN             NaN      NaN           NaN
# 990945      DAKAR      K   8900.0            16.0   9401.0        3134.0
# 322134      DAKAR      K  17100.0            11.0  18390.0        6130.0
# 2151229    UNKNOW      K      NaN             NaN      NaN           NaN
# 2027292     THIES      K    700.0             2.0    705.0         235.0
#
#          FREQUENCE  DATA_VOLUME  ON_NET  ORANGE  ...  RATIO_ON_NET_BY_ORANGE  \
# 219628         9.0       9118.0     NaN     NaN  ...                     NaN
# 1122719        2.0          NaN     1.0     8.0  ...                0.125000
# 365687         NaN          NaN     NaN     NaN  ...                     NaN
# 1708095        NaN          NaN     NaN     NaN  ...                     NaN
# 1118007        NaN          NaN     NaN     NaN  ...                     NaN
# ...            ...          ...     ...     ...  ...                     ...
# 2013547        NaN          NaN     NaN     NaN  ...                     NaN
# 990945        22.0          NaN   224.0   151.0  ...                1.483444
# 322134        12.0          NaN  1346.0   559.0  ...                2.407871
# 2151229        NaN          NaN     NaN     NaN  ...                     NaN
# 2027292        1.0          NaN   119.0    21.0  ...                5.666667
#
#          RATIO_ON_NET_BY_TIGO  HYPOTHENUS_FREQ_AND_FREQ_RECH  \
# 219628                    NaN                          162.0
# 1122719                   NaN                            5.0
# 365687                    NaN                            NaN
# 1708095                   NaN                            NaN
# 1118007                   NaN                            NaN
# ...                       ...                            ...
# 2013547                   NaN                            NaN
# 990945              17.230769                          740.0
# 322134              14.473118                          265.0
# 2151229                   NaN                            NaN
# 2027292                   NaN                            5.0
#
#          HYPOTHENUS_FREQ_AND_REGULARITY MEAN_PRICE_TOP_PACK  \
# 219628                           2106.0         5500.000000
# 1122719                           328.0                 NaN
# 365687                              NaN                 NaN
# 1708095                             NaN                 NaN
# 1118007                             NaN                 NaN
# ...                                 ...                 ...
# 2013547                             NaN                 NaN
# 990945                           3733.0          741.666667
# 322134                           3988.0         4275.000000
# 2151229                             NaN                 NaN
# 2027292                            65.0          700.000000
#
#          MENSUAL_BY_MEAN_PRICE_TOP_PACK  TENURE_REGION  \
# 219628                         1.000000     K_DIOURBEL
# 1122719                             NaN        K_DAKAR
# 365687                              NaN       K_UNKNOW
# 1708095                             NaN      K_KAOLACK
# 1118007                             NaN       K_UNKNOW
# ...                                 ...            ...
# 2013547                             NaN       K_UNKNOW
# 990945                        12.675506        K_DAKAR
# 322134                         4.301754        K_DAKAR
# 2151229                             NaN       K_UNKNOW
# 2027292                        1.007143        K_THIES
#
#                                        REGION_TOP_PACK  \
# 219628                       DIOURBEL_Data:490F=1GB,7d
# 1122719                                   DAKAR_UNKNOW
# 365687                                   UNKNOW_UNKNOW
# 1708095                                 KAOLACK_UNKNOW
# 1118007                                  UNKNOW_UNKNOW
# ...                                                ...
# 2013547                                  UNKNOW_UNKNOW
# 990945                     DAKAR_All-net 500F=2000F;5d
# 322134   DAKAR_MIXT: 200mnoff net _unl on net _5Go;30d
# 2151229                                  UNKNOW_UNKNOW
# 2027292           THIES_On net 200F=Unlimited _call24H
#
#                                    TOP_PACK_TENURE  \
# 219628                          Data:490F=1GB,7d_K
# 1122719                                   UNKNOW_K
# 365687                                    UNKNOW_K
# 1708095                                   UNKNOW_K
# 1118007                                   UNKNOW_K
# ...                                            ...
# 2013547                                   UNKNOW_K
# 990945                     All-net 500F=2000F;5d_K
# 322134   MIXT: 200mnoff net _unl on net _5Go;30d_K
# 2151229                                   UNKNOW_K
# 2027292           On net 200F=Unlimited _call24H_K
#
#                                   TENURE_REGION_TOP_PACK
# 219628                       K_DIOURBEL_Data:490F=1GB,7d
# 1122719                                   K_DAKAR_UNKNOW
# 365687                                   K_UNKNOW_UNKNOW
# 1708095                                 K_KAOLACK_UNKNOW
# 1118007                                  K_UNKNOW_UNKNOW
# ...                                                  ...
# 2013547                                  K_UNKNOW_UNKNOW
# 990945                     K_DAKAR_All-net 500F=2000F;5d
# 322134   K_DAKAR_MIXT: 200mnoff net _unl on net _5Go;30d
# 2151229                                  K_UNKNOW_UNKNOW
# 2027292           K_THIES_On net 200F=Unlimited _call24H
#
# [500000 rows x 30 columns]

# %% [markdown]
# # Regularization and mean encoding

# %%
"""from sklearn.model_selection import StratifiedKFold

y_tr=train_sample["CHURN"]
train_new=train_sample.copy()
train_new[cat_cols_mean]
skf=StratifiedKFold(n_splits=5,shuffle=True,random_state=123)
for tr_ind,val_ind in skf.split(train_sample,y_tr):
    X_tr,X_val=train_sample.iloc[tr_ind],train_sample.iloc[val_ind]
    for col in cat_cols:
        means=X_val[col].map(X_tr.groupby(col).CHURN.mean())
        X_val[col+'_MEAN_TARGET']=means
    #train_new.iloc[val_ind]=X_val
    train_new.loc[train_new.index[val_ind],cat_cols_mean]=X_val[cat_cols_mean]
prior=train_sample["CHURN"].mean()
#train_new.fillna(prior,inplace=True) 
train_new
"""

# %%
from sklearn import base
from sklearn.model_selection import KFold
class KFoldTargetEncoderTrain(base.BaseEstimator,
                               base.TransformerMixin):
    def __init__(self,colnames,targetName,
                  n_fold=5, verbosity=True,
                  discardOriginal_col=False):
        self.colnames = colnames
        self.targetName = targetName
        self.n_fold = n_fold
        self.verbosity = verbosity
        self.discardOriginal_col = discardOriginal_col
    def fit(self, X, y=None):
        return self
    def transform(self,X):
        assert(type(self.targetName) == str)
        assert(type(self.colnames) == str)
        assert(self.colnames in X.columns)
        assert(self.targetName in X.columns)
        mean_of_target = X[self.targetName].mean()
        kf = KFold(n_splits = self.n_fold,
                   shuffle = True, random_state=2019)
        col_mean_name = self.colnames + '_' + 'Kfold_Target_Enc'
        X[col_mean_name] = np.nan
        for tr_ind, val_ind in kf.split(X):
            X_tr, X_val = X.iloc[tr_ind], X.iloc[val_ind]
            X.loc[X.index[val_ind], col_mean_name] =X_val[self.colnames].map(X_tr.groupby(self.colnames)
                                     [self.targetName].mean())
            X[col_mean_name].fillna(mean_of_target, inplace = True)
        if self.verbosity:
            encoded_feature = X[col_mean_name].values
        if self.discardOriginal_col:
            X = X.drop(self.targetName, axis=1)
        return X

# %%
cat_cols_rafined=['TENURE',
 'REGION']
new_train = train_sample.copy()
for col in cat_cols_rafined:
    targetc = KFoldTargetEncoderTrain(col,"CHURN",n_fold=5)
    new_train = targetc.fit_transform(new_train)

# %%
new_train.head(5)
new_train.dtypes
# Out:
# REGION                             object
# TENURE                             object
# MONTANT                           float64
# FREQUENCE_RECH                    float64
# REVENUE                           float64
# ARPU_SEGMENT                      float64
# FREQUENCE                         float64
# DATA_VOLUME                       float64
# ON_NET                            float64
# ORANGE                            float64
# TIGO                              float64
# ZONE1                             float64
# ZONE2                             float64
# REGULARITY                          int64
# TOP_PACK                           object
# FREQ_TOP_PACK                     float64
# CHURN                               int64
# FREQUENCE_BY_FREQUENCE_RECH       float64
# sum_extra                         float64
# RATIO_ON_NET_BY_EXTRA_NET         float64
# RATIO_ON_NET_BY_ORANGE            float64
# RATIO_ON_NET_BY_TIGO              float64
# HYPOTHENUS_FREQ_AND_FREQ_RECH     float64
# HYPOTHENUS_FREQ_AND_REGULARITY    float64
# MEAN_PRICE_TOP_PACK               float64
# MENSUAL_BY_MEAN_PRICE_TOP_PACK    float64
# TENURE_REGION                      object
# REGION_TOP_PACK                    object
# TOP_PACK_TENURE                    object
# TENURE_REGION_TOP_PACK             object
# TENURE_Kfold_Target_Enc           float64
# REGION_Kfold_Target_Enc           float64
# dtype: object

# %%
# mean coding the test set
class KFoldTargetEncoderTest(base.BaseEstimator, base.TransformerMixin):
    
    def __init__(self,train,colNames,encodedName):
        
        self.train = train
        self.colNames = colNames
        self.encodedName = encodedName
        
    def fit(self, X, y=None):
        return self
    def transform(self,X):

        
        mean =  self.train[[self.colNames,
                self.encodedName]].groupby(
                                self.colNames).mean().reset_index() 
        print(mean)
        dd = {}
        for index, row in mean.iterrows():
            dd[row[self.colNames]] = row[self.encodedName]
        X[self.encodedName] = X[self.colNames]
        X = X.replace({self.encodedName: dd})
        return X

# %%
new_test=test.copy()
new_test
# Out:
#                                          user_id    REGION TENURE  MONTANT  \
# 0       00001dbe00e56fc4b1c1b65dda63de2a5ece55f9     THIES      K   5000.0
# 1       000055d41c8a62052dd426592e8a4a3342bf565d    UNKNOW      I    300.0
# 2       000081dd3245e6869a4a9c574c7050e7bb84c2c8     DAKAR      K   3300.0
# 3       0000b76d2145d9445d9ff6b65c9ebc4196c89337    UNKNOW      K      NaN
# 4       0000bae5480628cf8fe51ad84bcb39772fc79224    UNKNOW      K      NaN
# ...                                          ...       ...    ...      ...
# 380122  fffe7e03c7eede2ad0a728ee516c4d342dd16107     DAKAR      K   4000.0
# 380123  fffec230e6a1aa51ab37d0051ece42de611e71c6    UNKNOW      K      NaN
# 380124  ffff0dcc1ab9812bf205b6d76e9d084053cd96f5    UNKNOW      K   3950.0
# 380125  ffff91ea6a09a0c8ea42bc6ae33df4b5e06283dc    UNKNOW      K   3850.0
# 380126  ffffb393b346f5348034e6e22be93778d94d4beb  DIOURBEL      K      NaN
#
#         FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  DATA_VOLUME  ON_NET  \
# 0                  5.0   5000.0        1667.0        5.0          NaN   378.0
# 1                  2.0    326.0         109.0        3.0        397.0     NaN
# 2                 25.0   3400.0        1133.0       26.0       7150.0     0.0
# 3                  NaN      NaN           NaN        NaN          NaN     NaN
# 4                  NaN      NaN           NaN        NaN          NaN     NaN
# ...                ...      ...           ...        ...          ...     ...
# 380122             8.0   3999.0        1333.0        8.0       1587.0    26.0
# 380123             NaN      NaN           NaN        NaN          NaN     NaN
# 380124             7.0   3949.0        1316.0       10.0       1724.0    25.0
# 380125            18.0   3955.0        1318.0       23.0       2962.0     0.0
# 380126             NaN      NaN           NaN        NaN          NaN     0.0
#
#         ...  RATIO_ON_NET_BY_ORANGE  RATIO_ON_NET_BY_TIGO  \
# 0       ...               34.363636                  75.6
# 1       ...                     NaN                   NaN
# 2       ...                0.000000                   0.0
# 3       ...                     NaN                   NaN
# 4       ...                     NaN                   NaN
# ...     ...                     ...                   ...
# 380122  ...                0.104000                  26.0
# 380123  ...                     NaN                   NaN
# 380124  ...                0.352113                   NaN
# 380125  ...                0.000000                   NaN
# 380126  ...                     NaN                   NaN
#
#         HYPOTHENUS_FREQ_AND_FREQ_RECH  HYPOTHENUS_FREQ_AND_REGULARITY  \
# 0                                50.0                          1789.0
# 1                                13.0                          1690.0
# 2                              1301.0                          3925.0
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# ...                               ...                             ...
# 380122                          128.0                          2873.0
# 380123                            NaN                             NaN
# 380124                          149.0                           325.0
# 380125                          853.0                          1370.0
# 380126                            NaN                             NaN
#
#         MEAN_PRICE_TOP_PACK MENSUAL_BY_MEAN_PRICE_TOP_PACK  TENURE_REGION  \
# 0               1000.000000                       5.000000        K_THIES
# 1                300.000000                       1.086667       I_UNKNOW
# 2                150.000000                      22.666667        K_DAKAR
# 3                       NaN                            NaN       K_UNKNOW
# 4                       NaN                            NaN       K_UNKNOW
# ...                     ...                            ...            ...
# 380122           800.000000                       4.998750        K_DAKAR
# 380123                  NaN                            NaN       K_UNKNOW
# 380124           658.333333                       5.998481       K_UNKNOW
# 380125           350.000000                      11.300000       K_UNKNOW
# 380126                  NaN                            NaN     K_DIOURBEL
#
#                           REGION_TOP_PACK                TOP_PACK_TENURE  \
# 0           THIES_On-net 1000F=10MilF;10d      On-net 1000F=10MilF;10d_K
# 1             UNKNOW_Data: 100 F=40MB,24H         Data: 100 F=40MB,24H_I
# 2              DAKAR_Data: 100 F=40MB,24H         Data: 100 F=40MB,24H_K
# 3                           UNKNOW_UNKNOW                       UNKNOW_K
# 4                           UNKNOW_UNKNOW                       UNKNOW_K
# ...                                   ...                            ...
# 380122  DAKAR_Mixt 250F=Unlimited_call24H  Mixt 250F=Unlimited_call24H_K
# 380123                      UNKNOW_UNKNOW                       UNKNOW_K
# 380124         UNKNOW_IVR Echat_Daily_50F          IVR Echat_Daily_50F_K
# 380125        UNKNOW_Data: 100 F=40MB,24H         Data: 100 F=40MB,24H_K
# 380126                    DIOURBEL_UNKNOW                       UNKNOW_K
#
#                      TENURE_REGION_TOP_PACK
# 0           K_THIES_On-net 1000F=10MilF;10d
# 1             I_UNKNOW_Data: 100 F=40MB,24H
# 2              K_DAKAR_Data: 100 F=40MB,24H
# 3                           K_UNKNOW_UNKNOW
# 4                           K_UNKNOW_UNKNOW
# ...                                     ...
# 380122  K_DAKAR_Mixt 250F=Unlimited_call24H
# 380123                      K_UNKNOW_UNKNOW
# 380124         K_UNKNOW_IVR Echat_Daily_50F
# 380125        K_UNKNOW_Data: 100 F=40MB,24H
# 380126                    K_DIOURBEL_UNKNOW
#
# [380127 rows x 30 columns]

# %%
for col in cat_cols_rafined:
    test_targetc = KFoldTargetEncoderTest(new_train,
                                      col,
                                      col+'_Kfold_Target_Enc')
    new_test = test_targetc.fit_transform(new_test)
# Out:
#   TENURE  TENURE_Kfold_Target_Enc
# 0      D                 0.134964
# 1      E                 0.175105
# 2      F                 0.247292
# 3      G                 0.312336
# 4      H                 0.267059
# 5      I                 0.267591
# 6      J                 0.232440
# 7      K                 0.183263
#          REGION  REGION_Kfold_Target_Enc
# 0         DAKAR                 0.019122
# 1      DIOURBEL                 0.027267
# 2        FATICK                 0.016561
# 3      KAFFRINE                 0.007062
# 4       KAOLACK                 0.022308
# 5      KEDOUGOU                 0.048766
# 6         KOLDA                 0.010690
# 7         LOUGA                 0.016348
# 8         MATAM                 0.021183
# 9   SAINT-LOUIS                 0.012655
# 10      SEDHIOU                 0.036558
# 11  TAMBACOUNDA                 0.015652
# 12        THIES                 0.016845
# 13       UNKNOW                 0.448232
# 14   ZIGUINCHOR                 0.028303

# %%
new_test.dtypes
# Out:
# user_id                            object
# REGION                             object
# TENURE                             object
# MONTANT                           float64
# FREQUENCE_RECH                    float64
# REVENUE                           float64
# ARPU_SEGMENT                      float64
# FREQUENCE                         float64
# DATA_VOLUME                       float64
# ON_NET                            float64
# ORANGE                            float64
# TIGO                              float64
# ZONE1                             float64
# ZONE2                             float64
# REGULARITY                          int64
# TOP_PACK                           object
# FREQ_TOP_PACK                     float64
# FREQUENCE_BY_FREQUENCE_RECH       float64
# sum_extra                         float64
# RATIO_ON_NET_BY_EXTRA_NET         float64
# RATIO_ON_NET_BY_ORANGE            float64
# RATIO_ON_NET_BY_TIGO              float64
# HYPOTHENUS_FREQ_AND_FREQ_RECH     float64
# HYPOTHENUS_FREQ_AND_REGULARITY    float64
# MEAN_PRICE_TOP_PACK               float64
# MENSUAL_BY_MEAN_PRICE_TOP_PACK    float64
# TENURE_REGION                      object
# REGION_TOP_PACK                    object
# TOP_PACK_TENURE                    object
# TENURE_REGION_TOP_PACK             object
# TENURE_Kfold_Target_Enc           float64
# REGION_Kfold_Target_Enc           float64
# dtype: object

# %%
new_train.head(5)
# Out:
#            REGION TENURE  MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  \
# 219628   DIOURBEL      K   5500.0             9.0   5500.0        1833.0
# 1122719     DAKAR      K   1000.0             1.0   1000.0         333.0
# 365687     UNKNOW      K      NaN             NaN      NaN           NaN
# 1708095   KAOLACK      K      NaN             NaN      NaN           NaN
# 1118007    UNKNOW      K      NaN             NaN      NaN           NaN
#
#          FREQUENCE  DATA_VOLUME  ON_NET  ORANGE  ...  \
# 219628         9.0       9118.0     NaN     NaN  ...
# 1122719        2.0          NaN     1.0     8.0  ...
# 365687         NaN          NaN     NaN     NaN  ...
# 1708095        NaN          NaN     NaN     NaN  ...
# 1118007        NaN          NaN     NaN     NaN  ...
#
#          HYPOTHENUS_FREQ_AND_FREQ_RECH  HYPOTHENUS_FREQ_AND_REGULARITY  \
# 219628                           162.0                          2106.0
# 1122719                            5.0                           328.0
# 365687                             NaN                             NaN
# 1708095                            NaN                             NaN
# 1118007                            NaN                             NaN
#
#          MEAN_PRICE_TOP_PACK  MENSUAL_BY_MEAN_PRICE_TOP_PACK TENURE_REGION  \
# 219628                5500.0                             1.0    K_DIOURBEL
# 1122719                  NaN                             NaN       K_DAKAR
# 365687                   NaN                             NaN      K_UNKNOW
# 1708095                  NaN                             NaN     K_KAOLACK
# 1118007                  NaN                             NaN      K_UNKNOW
#
#                    REGION_TOP_PACK     TOP_PACK_TENURE  \
# 219628   DIOURBEL_Data:490F=1GB,7d  Data:490F=1GB,7d_K
# 1122719               DAKAR_UNKNOW            UNKNOW_K
# 365687               UNKNOW_UNKNOW            UNKNOW_K
# 1708095             KAOLACK_UNKNOW            UNKNOW_K
# 1118007              UNKNOW_UNKNOW            UNKNOW_K
#
#               TENURE_REGION_TOP_PACK  TENURE_Kfold_Target_Enc  \
# 219628   K_DIOURBEL_Data:490F=1GB,7d                 0.183084
# 1122719               K_DAKAR_UNKNOW                 0.183084
# 365687               K_UNKNOW_UNKNOW                 0.183271
# 1708095             K_KAOLACK_UNKNOW                 0.183050
# 1118007              K_UNKNOW_UNKNOW                 0.183050
#
#          REGION_Kfold_Target_Enc
# 219628                  0.027290
# 1122719                 0.018880
# 365687                  0.448232
# 1708095                 0.021929
# 1118007                 0.447872
#
# [5 rows x 32 columns]

# %% [markdown]
# # Correlation and vizualization

# %%
new_train.columns
# Out:
# Index(['REGION', 'TENURE', 'MONTANT', 'FREQUENCE_RECH', 'REVENUE',
#        'ARPU_SEGMENT', 'FREQUENCE', 'DATA_VOLUME', 'ON_NET', 'ORANGE', 'TIGO',
#        'ZONE1', 'ZONE2', 'REGULARITY', 'TOP_PACK', 'FREQ_TOP_PACK', 'CHURN',
#        'FREQUENCE_BY_FREQUENCE_RECH', 'sum_extra', 'RATIO_ON_NET_BY_EXTRA_NET',
#        'RATIO_ON_NET_BY_ORANGE', 'RATIO_ON_NET_BY_TIGO',
#        'HYPOTHENUS_FREQ_AND_FREQ_RECH', 'HYPOTHENUS_FREQ_AND_REGULARITY',
#        'MEAN_PRICE_TOP_PACK', 'MENSUAL_BY_MEAN_PRICE_TOP_PACK',
#        'TENURE_REGION', 'REGION_TOP_PACK', 'TOP_PACK_TENURE',
#        'TENURE_REGION_TOP_PACK', 'TENURE_Kfold_Target_Enc',
#        'REGION_Kfold_Target_Enc'],
#       dtype='object')

# %%
new_train.describe()
# Out:
#              MONTANT  FREQUENCE_RECH        REVENUE   ARPU_SEGMENT  \
# count  324260.000000   324260.000000  331503.000000  331503.000000
# mean     5516.868374       11.510010    5497.334422    1832.450738
# std      7026.919283       13.222252    7148.399258    2382.795536
# min        10.000000        1.000000       1.000000       0.000000
# 25%      1000.000000        2.000000    1000.000000     333.000000
# 50%      3000.000000        7.000000    3000.000000    1000.000000
# 75%      7300.000000       16.000000    7350.000000    2450.000000
# max    259500.000000      133.000000  397968.000000  132656.000000
#
#            FREQUENCE   DATA_VOLUME         ON_NET         ORANGE  \
# count  331503.000000  2.536970e+05  317669.000000  292243.000000
# mean       13.955077  3.352586e+03     277.988400      94.761979
# std        14.661360  1.315343e+04     859.610861     200.254704
# min         1.000000  0.000000e+00       0.000000       0.000000
# 25%         3.000000  0.000000e+00       5.000000       7.000000
# 50%         9.000000  2.540000e+02      27.000000      29.000000
# 75%        20.000000  2.898000e+03     157.000000      98.000000
# max        91.000000  1.297464e+06   29861.000000    7660.000000
#
#                 TIGO         ZONE1  ...      sum_extra  \
# count  200578.000000  39229.000000  ...  192387.000000
# mean       23.110585      8.431619  ...     151.621887
# std        63.701545     39.922624  ...     267.115529
# min         0.000000      0.000000  ...       0.500000
# 25%         2.000000      0.000000  ...      21.000000
# 50%         6.000000      1.000000  ...      64.000000
# 75%        20.000000      4.000000  ...     175.000000
# max      3486.000000   1804.000000  ...    7919.000000
#
#        RATIO_ON_NET_BY_EXTRA_NET  RATIO_ON_NET_BY_ORANGE  \
# count              183418.000000           267365.000000
# mean                    7.468624               15.839372
# std                    83.471192              165.452419
# min                     0.000000                0.000000
# 25%                     0.241935                0.306667
# 50%                     0.841667                1.131148
# 75%                     3.000000                4.628959
# max                 14456.000000            23024.000000
#
#        RATIO_ON_NET_BY_TIGO  HYPOTHENUS_FREQ_AND_FREQ_RECH  \
# count         189168.000000                  319165.000000
# mean              99.139887                     737.132753
# std              539.563179                    1579.427066
# min                0.000000                       2.000000
# 25%                1.634582                      20.000000
# 50%                7.174457                     136.000000
# 75%               34.500000                     666.000000
# max            39640.000000                   25970.000000
#
#        HYPOTHENUS_FREQ_AND_REGULARITY  MEAN_PRICE_TOP_PACK  \
# count                   331503.000000        288682.000000
# mean                      2246.934124           938.207711
# std                       1954.613790          1279.566988
# min                          2.000000             3.389831
# 25%                        485.000000           500.000000
# 50%                       1882.000000           637.500000
# 75%                       3690.000000          1000.000000
# max                      12125.000000        120000.000000
#
#        MENSUAL_BY_MEAN_PRICE_TOP_PACK  TENURE_Kfold_Target_Enc  \
# count                   288682.000000            500000.000000
# mean                         9.609301                 0.187505
# std                         13.558757                 0.019163
# min                          0.005500                 0.122137
# 25%                          2.000000                 0.183060
# 50%                          5.000000                 0.183084
# 75%                         12.024281                 0.183271
# max                       2006.885000                 0.314835
#
#        REGION_Kfold_Target_Enc
# count            500000.000000
# mean                  0.187506
# std                   0.210218
# min                   0.006253
# 25%                   0.017457
# 50%                   0.019397
# 75%                   0.447872
# max                   0.448842
#
# [8 rows x 25 columns]

# %%
new_train.corr()
# Out:
#                                  MONTANT  FREQUENCE_RECH   REVENUE  \
# MONTANT                         1.000000        0.797861  0.981480
# FREQUENCE_RECH                  0.797861        1.000000  0.803534
# REVENUE                         0.981480        0.803534  1.000000
# ARPU_SEGMENT                    0.981479        0.803533  1.000000
# FREQUENCE                       0.779294        0.955811  0.784766
# DATA_VOLUME                     0.295914        0.147304  0.304548
# ON_NET                          0.336082        0.410133  0.338823
# ORANGE                          0.659647        0.519051  0.660712
# TIGO                            0.410688        0.335939  0.407464
# ZONE1                           0.378936        0.138222  0.367184
# ZONE2                           0.409959        0.152732  0.387431
# REGULARITY                      0.527270        0.559070  0.533566
# FREQ_TOP_PACK                   0.737214        0.861819  0.745082
# CHURN                          -0.106495       -0.124906 -0.115067
# FREQUENCE_BY_FREQUENCE_RECH    -0.077766       -0.166849 -0.074073
# sum_extra                       0.674765        0.526151  0.673581
# RATIO_ON_NET_BY_EXTRA_NET       0.017693        0.028740  0.018464
# RATIO_ON_NET_BY_ORANGE          0.021994        0.024443  0.023100
# RATIO_ON_NET_BY_TIGO            0.069570        0.119408  0.070989
# HYPOTHENUS_FREQ_AND_FREQ_RECH   0.747046        0.923964  0.753288
# HYPOTHENUS_FREQ_AND_REGULARITY  0.723307        0.816865  0.728939
# MEAN_PRICE_TOP_PACK             0.220491       -0.066497  0.177861
# MENSUAL_BY_MEAN_PRICE_TOP_PACK  0.682485        0.799300  0.701531
# TENURE_Kfold_Target_Enc        -0.011907        0.000392 -0.011812
# REGION_Kfold_Target_Enc        -0.150462       -0.154184 -0.156698
#
#                                 ARPU_SEGMENT  FREQUENCE  DATA_VOLUME  \
# MONTANT                             0.981479   0.779294     0.295914
# FREQUENCE_RECH                      0.803533   0.955811     0.147304
# REVENUE                             1.000000   0.784766     0.304548
# ARPU_SEGMENT                        1.000000   0.784765     0.304549
# FREQUENCE                           0.784765   1.000000     0.165239
# DATA_VOLUME                         0.304549   0.165239     1.000000
# ON_NET                              0.338823   0.400346    -0.014003
# ORANGE                              0.660712   0.471147     0.063276
# TIGO                                0.407464   0.301265     0.018056
# ZONE1                               0.367183   0.120462     0.044143
# ZONE2                               0.387431   0.159370     0.047049
# REGULARITY                          0.533564   0.592125     0.184077
# FREQ_TOP_PACK                       0.745082   0.837775     0.115305
# CHURN                              -0.115067  -0.140780    -0.030259
# FREQUENCE_BY_FREQUENCE_RECH        -0.074075   0.004355    -0.015109
# sum_extra                           0.673581   0.472792     0.050127
# RATIO_ON_NET_BY_EXTRA_NET           0.018464   0.027906    -0.013738
# RATIO_ON_NET_BY_ORANGE              0.023101   0.020974    -0.014191
# RATIO_ON_NET_BY_TIGO                0.070988   0.121533    -0.034789
# HYPOTHENUS_FREQ_AND_FREQ_RECH       0.753288   0.905685     0.133760
# HYPOTHENUS_FREQ_AND_REGULARITY      0.728938   0.848633     0.196988
# MEAN_PRICE_TOP_PACK                 0.177861  -0.019365     0.229830
# MENSUAL_BY_MEAN_PRICE_TOP_PACK      0.701531   0.784884     0.108573
# TENURE_Kfold_Target_Enc            -0.011812   0.001873     0.012572
# REGION_Kfold_Target_Enc            -0.156698  -0.173853    -0.019416
#
#                                   ON_NET    ORANGE      TIGO     ZONE1  ...  \
# MONTANT                         0.336082  0.659647  0.410688  0.378936  ...
# FREQUENCE_RECH                  0.410133  0.519051  0.335939  0.138222  ...
# REVENUE                         0.338823  0.660712  0.407464  0.367184  ...
# ARPU_SEGMENT                    0.338823  0.660712  0.407464  0.367183  ...
# FREQUENCE                       0.400346  0.471147  0.301265  0.120462  ...
# DATA_VOLUME                    -0.014003  0.063276  0.018056  0.044143  ...
# ON_NET                          1.000000  0.227353  0.135380  0.015763  ...
# ORANGE                          0.227353  1.000000  0.399023  0.059221  ...
# TIGO                            0.135380  0.399023  1.000000  0.009550  ...
# ZONE1                           0.015763  0.059221  0.009550  1.000000  ...
# ZONE2                          -0.019139  0.015651  0.008380  0.063339  ...
# REGULARITY                      0.275679  0.313354  0.192360  0.051214  ...
# FREQ_TOP_PACK                   0.357742  0.546817  0.358670  0.200864  ...
# CHURN                          -0.060078 -0.063997 -0.035845  0.013927  ...
# FREQUENCE_BY_FREQUENCE_RECH    -0.052746 -0.068666 -0.049896 -0.025670  ...
# sum_extra                       0.215788  0.975021  0.592722  0.057730  ...
# RATIO_ON_NET_BY_EXTRA_NET       0.189062 -0.033741 -0.020373 -0.005987  ...
# RATIO_ON_NET_BY_ORANGE          0.198542 -0.038049 -0.012664 -0.005511  ...
# RATIO_ON_NET_BY_TIGO            0.439023  0.012454 -0.057629 -0.003698  ...
# HYPOTHENUS_FREQ_AND_FREQ_RECH   0.401399  0.502961  0.327708  0.115551  ...
# HYPOTHENUS_FREQ_AND_REGULARITY  0.387708  0.447604  0.288298  0.086573  ...
# MEAN_PRICE_TOP_PACK            -0.015569  0.076529  0.017449  0.044787  ...
# MENSUAL_BY_MEAN_PRICE_TOP_PACK  0.335184  0.513085  0.331876  0.197790  ...
# TENURE_Kfold_Target_Enc        -0.004709 -0.020798 -0.012490  0.016971  ...
# REGION_Kfold_Target_Enc        -0.079303 -0.101511 -0.053304 -0.004523  ...
#
#                                 sum_extra  RATIO_ON_NET_BY_EXTRA_NET  \
# MONTANT                          0.674765                   0.017693
# FREQUENCE_RECH                   0.526151                   0.028740
# REVENUE                          0.673581                   0.018464
# ARPU_SEGMENT                     0.673581                   0.018464
# FREQUENCE                        0.472792                   0.027906
# DATA_VOLUME                      0.050127                  -0.013738
# ON_NET                           0.215788                   0.189062
# ORANGE                           0.975021                  -0.033741
# TIGO                             0.592722                  -0.020373
# ZONE1                            0.057730                  -0.005987
# ZONE2                            0.007999                  -0.009523
# REGULARITY                       0.310129                   0.032485
# FREQ_TOP_PACK                    0.573321                   0.023672
# CHURN                           -0.054043                  -0.001351
# FREQUENCE_BY_FREQUENCE_RECH     -0.070110                  -0.009998
# sum_extra                        1.000000                  -0.034585
# RATIO_ON_NET_BY_EXTRA_NET       -0.034585                   1.000000
# RATIO_ON_NET_BY_ORANGE          -0.039850                   0.788110
# RATIO_ON_NET_BY_TIGO            -0.003351                   0.358095
# HYPOTHENUS_FREQ_AND_FREQ_RECH    0.514337                   0.020029
# HYPOTHENUS_FREQ_AND_REGULARITY   0.458443                   0.033202
# MEAN_PRICE_TOP_PACK              0.064756                  -0.015100
# MENSUAL_BY_MEAN_PRICE_TOP_PACK   0.531232                   0.021629
# TENURE_Kfold_Target_Enc         -0.020431                  -0.002968
# REGION_Kfold_Target_Enc         -0.094192                  -0.001046
#
#                                 RATIO_ON_NET_BY_ORANGE  RATIO_ON_NET_BY_TIGO  \
# MONTANT                                       0.021994              0.069570
# FREQUENCE_RECH                                0.024443              0.119408
# REVENUE                                       0.023100              0.070989
# ARPU_SEGMENT                                  0.023101              0.070988
# FREQUENCE                                     0.020974              0.121533
# DATA_VOLUME                                  -0.014191             -0.034789
# ON_NET                                        0.198542              0.439023
# ORANGE                                       -0.038049              0.012454
# TIGO                                         -0.012664             -0.057629
# ZONE1                                        -0.005511             -0.003698
# ZONE2                                        -0.005591             -0.012095
# REGULARITY                                    0.035402              0.098012
# FREQ_TOP_PACK                                 0.022054              0.100320
# CHURN                                        -0.005032             -0.014586
# FREQUENCE_BY_FREQUENCE_RECH                  -0.013450             -0.022979
# sum_extra                                    -0.039850             -0.003351
# RATIO_ON_NET_BY_EXTRA_NET                     0.788110              0.358095
# RATIO_ON_NET_BY_ORANGE                        1.000000              0.252413
# RATIO_ON_NET_BY_TIGO                          0.252413              1.000000
# HYPOTHENUS_FREQ_AND_FREQ_RECH                 0.012253              0.105176
# HYPOTHENUS_FREQ_AND_REGULARITY                0.030808              0.124210
# MEAN_PRICE_TOP_PACK                          -0.013549             -0.030410
# MENSUAL_BY_MEAN_PRICE_TOP_PACK                0.020607              0.091769
# TENURE_Kfold_Target_Enc                       0.000184             -0.002865
# REGION_Kfold_Target_Enc                      -0.001831             -0.013491
#
#                                 HYPOTHENUS_FREQ_AND_FREQ_RECH  \
# MONTANT                                              0.747046
# FREQUENCE_RECH                                       0.923964
# REVENUE                                              0.753288
# ARPU_SEGMENT                                         0.753288
# FREQUENCE                                            0.905685
# DATA_VOLUME                                          0.133760
# ON_NET                                               0.401399
# ORANGE                                               0.502961
# TIGO                                                 0.327708
# ZONE1                                                0.115551
# ZONE2                                                0.158175
# REGULARITY                                           0.417120
# FREQ_TOP_PACK                                        0.840296
# CHURN                                               -0.077716
# FREQUENCE_BY_FREQUENCE_RECH                         -0.054033
# sum_extra                                            0.514337
# RATIO_ON_NET_BY_EXTRA_NET                            0.020029
# RATIO_ON_NET_BY_ORANGE                               0.012253
# RATIO_ON_NET_BY_TIGO                                 0.105176
# HYPOTHENUS_FREQ_AND_FREQ_RECH                        1.000000
# HYPOTHENUS_FREQ_AND_REGULARITY                       0.763193
# MEAN_PRICE_TOP_PACK                                 -0.044738
# MENSUAL_BY_MEAN_PRICE_TOP_PACK                       0.784809
# TENURE_Kfold_Target_Enc                              0.003796
# REGION_Kfold_Target_Enc                             -0.105662
#
#                                 HYPOTHENUS_FREQ_AND_REGULARITY  \
# MONTANT                                               0.723307
# FREQUENCE_RECH                                        0.816865
# REVENUE                                               0.728939
# ARPU_SEGMENT                                          0.728938
# FREQUENCE                                             0.848633
# DATA_VOLUME                                           0.196988
# ON_NET                                                0.387708
# ORANGE                                                0.447604
# TIGO                                                  0.288298
# ZONE1                                                 0.086573
# ZONE2                                                 0.126646
# REGULARITY                                            0.887917
# FREQ_TOP_PACK                                         0.710011
# CHURN                                                -0.219385
# FREQUENCE_BY_FREQUENCE_RECH                          -0.037011
# sum_extra                                             0.458443
# RATIO_ON_NET_BY_EXTRA_NET                             0.033202
# RATIO_ON_NET_BY_ORANGE                                0.030808
# RATIO_ON_NET_BY_TIGO                                  0.124210
# HYPOTHENUS_FREQ_AND_FREQ_RECH                         0.763193
# HYPOTHENUS_FREQ_AND_REGULARITY                        1.000000
# MEAN_PRICE_TOP_PACK                                   0.049060
# MENSUAL_BY_MEAN_PRICE_TOP_PACK                        0.664570
# TENURE_Kfold_Target_Enc                              -0.005432
# REGION_Kfold_Target_Enc                              -0.275902
#
#                                 MEAN_PRICE_TOP_PACK  \
# MONTANT                                    0.220491
# FREQUENCE_RECH                            -0.066497
# REVENUE                                    0.177861
# ARPU_SEGMENT                               0.177861
# FREQUENCE                                 -0.019365
# DATA_VOLUME                                0.229830
# ON_NET                                    -0.015569
# ORANGE                                     0.076529
# TIGO                                       0.017449
# ZONE1                                      0.044787
# ZONE2                                      0.222384
# REGULARITY                                 0.089058
# FREQ_TOP_PACK                             -0.169357
# CHURN                                      0.001001
# FREQUENCE_BY_FREQUENCE_RECH                0.132371
# sum_extra                                  0.064756
# RATIO_ON_NET_BY_EXTRA_NET                 -0.015100
# RATIO_ON_NET_BY_ORANGE                    -0.013549
# RATIO_ON_NET_BY_TIGO                      -0.030410
# HYPOTHENUS_FREQ_AND_FREQ_RECH             -0.044738
# HYPOTHENUS_FREQ_AND_REGULARITY             0.049060
# MEAN_PRICE_TOP_PACK                        1.000000
# MENSUAL_BY_MEAN_PRICE_TOP_PACK            -0.163478
# TENURE_Kfold_Target_Enc                   -0.009405
# REGION_Kfold_Target_Enc                   -0.013449
#
#                                 MENSUAL_BY_MEAN_PRICE_TOP_PACK  \
# MONTANT                                               0.682485
# FREQUENCE_RECH                                        0.799300
# REVENUE                                               0.701531
# ARPU_SEGMENT                                          0.701531
# FREQUENCE                                             0.784884
# DATA_VOLUME                                           0.108573
# ON_NET                                                0.335184
# ORANGE                                                0.513085
# TIGO                                                  0.331876
# ZONE1                                                 0.197790
# ZONE2                                                 0.074160
# REGULARITY                                            0.414113
# FREQ_TOP_PACK                                         0.937441
# CHURN                                                -0.078401
# FREQUENCE_BY_FREQUENCE_RECH                           0.005853
# sum_extra                                             0.531232
# RATIO_ON_NET_BY_EXTRA_NET                             0.021629
# RATIO_ON_NET_BY_ORANGE                                0.020607
# RATIO_ON_NET_BY_TIGO                                  0.091769
# HYPOTHENUS_FREQ_AND_FREQ_RECH                         0.784809
# HYPOTHENUS_FREQ_AND_REGULARITY                        0.664570
# MEAN_PRICE_TOP_PACK                                  -0.163478
# MENSUAL_BY_MEAN_PRICE_TOP_PACK                        1.000000
# TENURE_Kfold_Target_Enc                              -0.004589
# REGION_Kfold_Target_Enc                              -0.104362
#
#                                 TENURE_Kfold_Target_Enc  \
# MONTANT                                       -0.011907
# FREQUENCE_RECH                                 0.000392
# REVENUE                                       -0.011812
# ARPU_SEGMENT                                  -0.011812
# FREQUENCE                                      0.001873
# DATA_VOLUME                                    0.012572
# ON_NET                                        -0.004709
# ORANGE                                        -0.020798
# TIGO                                          -0.012490
# ZONE1                                          0.016971
# ZONE2                                          0.001549
# REGULARITY                                    -0.032501
# FREQ_TOP_PACK                                 -0.004753
# CHURN                                          0.048771
# FREQUENCE_BY_FREQUENCE_RECH                   -0.001983
# sum_extra                                     -0.020431
# RATIO_ON_NET_BY_EXTRA_NET                     -0.002968
# RATIO_ON_NET_BY_ORANGE                         0.000184
# RATIO_ON_NET_BY_TIGO                          -0.002865
# HYPOTHENUS_FREQ_AND_FREQ_RECH                  0.003796
# HYPOTHENUS_FREQ_AND_REGULARITY                -0.005432
# MEAN_PRICE_TOP_PACK                           -0.009405
# MENSUAL_BY_MEAN_PRICE_TOP_PACK                -0.004589
# TENURE_Kfold_Target_Enc                        1.000000
# REGION_Kfold_Target_Enc                        0.047561
#
#                                 REGION_Kfold_Target_Enc
# MONTANT                                       -0.150462
# FREQUENCE_RECH                                -0.154184
# REVENUE                                       -0.156698
# ARPU_SEGMENT                                  -0.156698
# FREQUENCE                                     -0.173853
# DATA_VOLUME                                   -0.019416
# ON_NET                                        -0.079303
# ORANGE                                        -0.101511
# TIGO                                          -0.053304
# ZONE1                                         -0.004523
# ZONE2                                         -0.000513
# REGULARITY                                    -0.533809
# FREQ_TOP_PACK                                 -0.114853
# CHURN                                          0.538567
# FREQUENCE_BY_FREQUENCE_RECH                   -0.004240
# sum_extra                                     -0.094192
# RATIO_ON_NET_BY_EXTRA_NET                     -0.001046
# RATIO_ON_NET_BY_ORANGE                        -0.001831
# RATIO_ON_NET_BY_TIGO                          -0.013491
# HYPOTHENUS_FREQ_AND_FREQ_RECH                 -0.105662
# HYPOTHENUS_FREQ_AND_REGULARITY                -0.275902
# MEAN_PRICE_TOP_PACK                           -0.013449
# MENSUAL_BY_MEAN_PRICE_TOP_PACK                -0.104362
# TENURE_Kfold_Target_Enc                        0.047561
# REGION_Kfold_Target_Enc                        1.000000
#
# [25 rows x 25 columns]

# %%
#sns.pairplot(train_sample)
new_test

# %%
new_train["CHURN"]=new_train["CHURN"].astype("category")

for attri in cat_cols:
    new_train[attri]=new_train[attri].astype("category")
    new_test[attri]=new_test[attri].astype("category")

# %%
new_test.tail(10)
# Out:
#                                          user_id       REGION TENURE  MONTANT  \
# 380117  fffd954647f34b38b527dd2dfbfecb49edbdf8f7        THIES      K  20000.0
# 380118  fffe4dfd57392c8d7ddfd48cb51bef3c8adb0892       UNKNOW      H   1000.0
# 380119  fffe51167f1ad1bf26dda45ccfc40b5d7fab8384  SAINT-LOUIS      F  43500.0
# 380120  fffe5c84e3db939182ee2a3a3123920025eca8a3  SAINT-LOUIS      K   3300.0
# 380121  fffe7c538a7d66446ee6f66c0b11b5446ec1be68        MATAM      K   4700.0
# 380122  fffe7e03c7eede2ad0a728ee516c4d342dd16107        DAKAR      K   4000.0
# 380123  fffec230e6a1aa51ab37d0051ece42de611e71c6       UNKNOW      K      NaN
# 380124  ffff0dcc1ab9812bf205b6d76e9d084053cd96f5       UNKNOW      K   3950.0
# 380125  ffff91ea6a09a0c8ea42bc6ae33df4b5e06283dc       UNKNOW      K   3850.0
# 380126  ffffb393b346f5348034e6e22be93778d94d4beb     DIOURBEL      K      NaN
#
#         FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  DATA_VOLUME  ON_NET  \
# 380117            27.0  20001.0        6667.0       35.0      74350.0    55.0
# 380118             2.0    991.0         330.0        2.0       1507.0     NaN
# 380119            75.0  44537.0       14846.0       75.0          0.0  1611.0
# 380120             7.0   3299.0        1100.0        7.0          NaN    80.0
# 380121            28.0   4915.0        1638.0       38.0       3942.0     1.0
# 380122             8.0   3999.0        1333.0        8.0       1587.0    26.0
# 380123             NaN      NaN           NaN        NaN          NaN     NaN
# 380124             7.0   3949.0        1316.0       10.0       1724.0    25.0
# 380125            18.0   3955.0        1318.0       23.0       2962.0     0.0
# 380126             NaN      NaN           NaN        NaN          NaN     0.0
#
#         ...  HYPOTHENUS_FREQ_AND_FREQ_RECH  HYPOTHENUS_FREQ_AND_REGULARITY  \
# 380117  ...                         1954.0                          5069.0
# 380118  ...                            8.0                            20.0
# 380119  ...                        11250.0                          9469.0
# 380120  ...                           98.0                          2753.0
# 380121  ...                         2228.0                          3944.0
# 380122  ...                          128.0                          2873.0
# 380123  ...                            NaN                             NaN
# 380124  ...                          149.0                           325.0
# 380125  ...                          853.0                          1370.0
# 380126  ...                            NaN                             NaN
#
#         MEAN_PRICE_TOP_PACK  MENSUAL_BY_MEAN_PRICE_TOP_PACK  TENURE_REGION  \
# 380117          1333.333333                       15.000750        K_THIES
# 380118           500.000000                        1.982000       H_UNKNOW
# 380119           500.000000                       89.074000  F_SAINT-LOUIS
# 380120           825.000000                        3.998788  K_SAINT-LOUIS
# 380121           142.424242                       34.509574        K_MATAM
# 380122           800.000000                        4.998750        K_DAKAR
# 380123                  NaN                             NaN       K_UNKNOW
# 380124           658.333333                        5.998481       K_UNKNOW
# 380125           350.000000                       11.300000       K_UNKNOW
# 380126                  NaN                             NaN     K_DIOURBEL
#
#                           REGION_TOP_PACK                TOP_PACK_TENURE  \
# 380117            THIES_Data:1000F=5GB,7d            Data:1000F=5GB,7d_K
# 380118            UNKNOW_Data:490F=1GB,7d             Data:490F=1GB,7d_H
# 380119            SAINT-LOUIS_Jokko_Daily                  Jokko_Daily_F
# 380120  SAINT-LOUIS_All-net 500F=2000F;5d        All-net 500F=2000F;5d_K
# 380121         MATAM_Data: 100 F=40MB,24H         Data: 100 F=40MB,24H_K
# 380122  DAKAR_Mixt 250F=Unlimited_call24H  Mixt 250F=Unlimited_call24H_K
# 380123                      UNKNOW_UNKNOW                       UNKNOW_K
# 380124         UNKNOW_IVR Echat_Daily_50F          IVR Echat_Daily_50F_K
# 380125        UNKNOW_Data: 100 F=40MB,24H         Data: 100 F=40MB,24H_K
# 380126                    DIOURBEL_UNKNOW                       UNKNOW_K
#
#                      TENURE_REGION_TOP_PACK  TENURE_Kfold_Target_Enc  \
# 380117            K_THIES_Data:1000F=5GB,7d                 0.183263
# 380118            H_UNKNOW_Data:490F=1GB,7d                 0.267059
# 380119            F_SAINT-LOUIS_Jokko_Daily                 0.247292
# 380120  K_SAINT-LOUIS_All-net 500F=2000F;5d                 0.183263
# 380121         K_MATAM_Data: 100 F=40MB,24H                 0.183263
# 380122  K_DAKAR_Mixt 250F=Unlimited_call24H                 0.183263
# 380123                      K_UNKNOW_UNKNOW                 0.183263
# 380124         K_UNKNOW_IVR Echat_Daily_50F                 0.183263
# 380125        K_UNKNOW_Data: 100 F=40MB,24H                 0.183263
# 380126                    K_DIOURBEL_UNKNOW                 0.183263
#
#         REGION_Kfold_Target_Enc
# 380117                 0.016845
# 380118                 0.448232
# 380119                 0.012655
# 380120                 0.012655
# 380121                 0.021183
# 380122                 0.019122
# 380123                 0.448232
# 380124                 0.448232
# 380125                 0.448232
# 380126                 0.027267
#
# [10 rows x 32 columns]

# %%
new_test.dtypes
# Out:
# user_id                             object
# REGION                            category
# TENURE                            category
# MONTANT                            float64
# FREQUENCE_RECH                     float64
# REVENUE                            float64
# ARPU_SEGMENT                       float64
# FREQUENCE                          float64
# DATA_VOLUME                        float64
# ON_NET                             float64
# ORANGE                             float64
# TIGO                               float64
# ZONE1                              float64
# ZONE2                              float64
# REGULARITY                           int64
# TOP_PACK                          category
# FREQ_TOP_PACK                      float64
# FREQUENCE_BY_FREQUENCE_RECH        float64
# sum_extra                          float64
# RATIO_ON_NET_BY_EXTRA_NET          float64
# RATIO_ON_NET_BY_ORANGE             float64
# RATIO_ON_NET_BY_TIGO               float64
# HYPOTHENUS_FREQ_AND_FREQ_RECH      float64
# HYPOTHENUS_FREQ_AND_REGULARITY     float64
# MEAN_PRICE_TOP_PACK                float64
# MENSUAL_BY_MEAN_PRICE_TOP_PACK     float64
# TENURE_REGION                     category
# REGION_TOP_PACK                   category
# TOP_PACK_TENURE                   category
# TENURE_REGION_TOP_PACK            category
# TENURE_Kfold_Target_Enc            float64
# REGION_Kfold_Target_Enc            float64
# dtype: object

# %%
test_prepared=new_test
test_prepared
# Out:
#           REGION TENURE  MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  \
# 0          THIES      K   5000.0             5.0   5000.0        1667.0
# 1         UNKNOW      I    300.0             2.0    326.0         109.0
# 2          DAKAR      K   3300.0            25.0   3400.0        1133.0
# 3         UNKNOW      K      NaN             NaN      NaN           NaN
# 4         UNKNOW      K      NaN             NaN      NaN           NaN
# ...          ...    ...      ...             ...      ...           ...
# 380122     DAKAR      K   4000.0             8.0   3999.0        1333.0
# 380123    UNKNOW      K      NaN             NaN      NaN           NaN
# 380124    UNKNOW      K   3950.0             7.0   3949.0        1316.0
# 380125    UNKNOW      K   3850.0            18.0   3955.0        1318.0
# 380126  DIOURBEL      K      NaN             NaN      NaN           NaN
#
#         FREQUENCE  DATA_VOLUME  ON_NET  ORANGE  ...  \
# 0             5.0          NaN   378.0    11.0  ...
# 1             3.0        397.0     NaN     0.0  ...
# 2            26.0       7150.0     0.0     2.0  ...
# 3             NaN          NaN     NaN     NaN  ...
# 4             NaN          NaN     NaN     NaN  ...
# ...           ...          ...     ...     ...  ...
# 380122        8.0       1587.0    26.0   250.0  ...
# 380123        NaN          NaN     NaN     NaN  ...
# 380124       10.0       1724.0    25.0    71.0  ...
# 380125       23.0       2962.0     0.0     7.0  ...
# 380126        NaN          NaN     0.0     NaN  ...
#
#         HYPOTHENUS_FREQ_AND_FREQ_RECH  HYPOTHENUS_FREQ_AND_REGULARITY  \
# 0                                50.0                          1789.0
# 1                                13.0                          1690.0
# 2                              1301.0                          3925.0
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# ...                               ...                             ...
# 380122                          128.0                          2873.0
# 380123                            NaN                             NaN
# 380124                          149.0                           325.0
# 380125                          853.0                          1370.0
# 380126                            NaN                             NaN
#
#         MEAN_PRICE_TOP_PACK  MENSUAL_BY_MEAN_PRICE_TOP_PACK TENURE_REGION  \
# 0               1000.000000                        5.000000       K_THIES
# 1                300.000000                        1.086667      I_UNKNOW
# 2                150.000000                       22.666667       K_DAKAR
# 3                       NaN                             NaN      K_UNKNOW
# 4                       NaN                             NaN      K_UNKNOW
# ...                     ...                             ...           ...
# 380122           800.000000                        4.998750       K_DAKAR
# 380123                  NaN                             NaN      K_UNKNOW
# 380124           658.333333                        5.998481      K_UNKNOW
# 380125           350.000000                       11.300000      K_UNKNOW
# 380126                  NaN                             NaN    K_DIOURBEL
#
#                           REGION_TOP_PACK                TOP_PACK_TENURE  \
# 0           THIES_On-net 1000F=10MilF;10d      On-net 1000F=10MilF;10d_K
# 1             UNKNOW_Data: 100 F=40MB,24H         Data: 100 F=40MB,24H_I
# 2              DAKAR_Data: 100 F=40MB,24H         Data: 100 F=40MB,24H_K
# 3                           UNKNOW_UNKNOW                       UNKNOW_K
# 4                           UNKNOW_UNKNOW                       UNKNOW_K
# ...                                   ...                            ...
# 380122  DAKAR_Mixt 250F=Unlimited_call24H  Mixt 250F=Unlimited_call24H_K
# 380123                      UNKNOW_UNKNOW                       UNKNOW_K
# 380124         UNKNOW_IVR Echat_Daily_50F          IVR Echat_Daily_50F_K
# 380125        UNKNOW_Data: 100 F=40MB,24H         Data: 100 F=40MB,24H_K
# 380126                    DIOURBEL_UNKNOW                       UNKNOW_K
#
#                      TENURE_REGION_TOP_PACK  TENURE_Kfold_Target_Enc  \
# 0           K_THIES_On-net 1000F=10MilF;10d                 0.183263
# 1             I_UNKNOW_Data: 100 F=40MB,24H                 0.267591
# 2              K_DAKAR_Data: 100 F=40MB,24H                 0.183263
# 3                           K_UNKNOW_UNKNOW                 0.183263
# 4                           K_UNKNOW_UNKNOW                 0.183263
# ...                                     ...                      ...
# 380122  K_DAKAR_Mixt 250F=Unlimited_call24H                 0.183263
# 380123                      K_UNKNOW_UNKNOW                 0.183263
# 380124         K_UNKNOW_IVR Echat_Daily_50F                 0.183263
# 380125        K_UNKNOW_Data: 100 F=40MB,24H                 0.183263
# 380126                    K_DIOURBEL_UNKNOW                 0.183263
#
#         REGION_Kfold_Target_Enc
# 0                      0.016845
# 1                      0.448232
# 2                      0.019122
# 3                      0.448232
# 4                      0.448232
# ...                         ...
# 380122                 0.019122
# 380123                 0.448232
# 380124                 0.448232
# 380125                 0.448232
# 380126                 0.027267
#
# [380127 rows x 31 columns]

# %%
train_labels=new_train["CHURN"].copy()
train_prepared=new_train.drop("CHURN",axis=1)
train_prepared.dtypes
# Out:
# REGION                            category
# TENURE                            category
# MONTANT                            float64
# FREQUENCE_RECH                     float64
# REVENUE                            float64
# ARPU_SEGMENT                       float64
# FREQUENCE                          float64
# DATA_VOLUME                        float64
# ON_NET                             float64
# ORANGE                             float64
# TIGO                               float64
# ZONE1                              float64
# ZONE2                              float64
# REGULARITY                           int64
# TOP_PACK                          category
# FREQ_TOP_PACK                      float64
# FREQUENCE_BY_FREQUENCE_RECH        float64
# sum_extra                          float64
# RATIO_ON_NET_BY_EXTRA_NET          float64
# RATIO_ON_NET_BY_ORANGE             float64
# RATIO_ON_NET_BY_TIGO               float64
# HYPOTHENUS_FREQ_AND_FREQ_RECH      float64
# HYPOTHENUS_FREQ_AND_REGULARITY     float64
# MEAN_PRICE_TOP_PACK                float64
# MENSUAL_BY_MEAN_PRICE_TOP_PACK     float64
# TENURE_REGION                     category
# REGION_TOP_PACK                   category
# TOP_PACK_TENURE                   category
# TENURE_REGION_TOP_PACK            category
# TENURE_Kfold_Target_Enc            float64
# REGION_Kfold_Target_Enc            float64
# dtype: object

# %%
cat_cols=["TENURE","REGION","TOP_PACK","TENURE_REGION","REGION_TOP_PACK","TOP_PACK_TENURE","TENURE_REGION_TOP_PACK"]
num_cols=[ x for x in train_prepared.columns if x not in cat_cols ]
num_cols
# Out:
# ['MONTANT',
#  'FREQUENCE_RECH',
#  'REVENUE',
#  'ARPU_SEGMENT',
#  'FREQUENCE',
#  'DATA_VOLUME',
#  'ON_NET',
#  'ORANGE',
#  'TIGO',
#  'ZONE1',
#  'ZONE2',
#  'REGULARITY',
#  'FREQ_TOP_PACK',
#  'FREQUENCE_BY_FREQUENCE_RECH',
#  'sum_extra',
#  'RATIO_ON_NET_BY_EXTRA_NET',
#  'RATIO_ON_NET_BY_ORANGE',
#  'RATIO_ON_NET_BY_TIGO',
#  'HYPOTHENUS_FREQ_AND_FREQ_RECH',
#  'HYPOTHENUS_FREQ_AND_REGULARITY',
#  'MEAN_PRICE_TOP_PACK',
#  'MENSUAL_BY_MEAN_PRICE_TOP_PACK',
#  'TENURE_Kfold_Target_Enc',
#  'REGION_Kfold_Target_Enc']

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
num_pipeline = Pipeline([
('std_scaler', StandardScaler())
])
full_pipeline = ColumnTransformer([
         ("num",num_pipeline,num_cols),
        ("cat", OneHotEncoder(), cat_cols)
],remainder='passthrough')

# %%
new_train.dtypes
# Out:
# REGION                            category
# TENURE                            category
# MONTANT                            float64
# FREQUENCE_RECH                     float64
# REVENUE                            float64
# ARPU_SEGMENT                       float64
# FREQUENCE                          float64
# DATA_VOLUME                        float64
# ON_NET                             float64
# ORANGE                             float64
# TIGO                               float64
# ZONE1                              float64
# ZONE2                              float64
# REGULARITY                           int64
# TOP_PACK                          category
# FREQ_TOP_PACK                      float64
# CHURN                             category
# FREQUENCE_BY_FREQUENCE_RECH        float64
# sum_extra                          float64
# RATIO_ON_NET_BY_EXTRA_NET          float64
# RATIO_ON_NET_BY_ORANGE             float64
# RATIO_ON_NET_BY_TIGO               float64
# HYPOTHENUS_FREQ_AND_FREQ_RECH      float64
# HYPOTHENUS_FREQ_AND_REGULARITY     float64
# MEAN_PRICE_TOP_PACK                float64
# MENSUAL_BY_MEAN_PRICE_TOP_PACK     float64
# TENURE_REGION                     category
# REGION_TOP_PACK                   category
# TOP_PACK_TENURE                   category
# TENURE_REGION_TOP_PACK            category
# TENURE_Kfold_Target_Enc            float64
# REGION_Kfold_Target_Enc            float64
# dtype: object

# %%
test_prepared.head(5)
# Out:
#    REGION TENURE  MONTANT  FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  \
# 0   THIES      K   5000.0             5.0   5000.0        1667.0        5.0
# 1  UNKNOW      I    300.0             2.0    326.0         109.0        3.0
# 2   DAKAR      K   3300.0            25.0   3400.0        1133.0       26.0
# 3  UNKNOW      K      NaN             NaN      NaN           NaN        NaN
# 4  UNKNOW      K      NaN             NaN      NaN           NaN        NaN
#
#    DATA_VOLUME  ON_NET  ORANGE  ...  HYPOTHENUS_FREQ_AND_FREQ_RECH  \
# 0          NaN   378.0    11.0  ...                           50.0
# 1        397.0     NaN     0.0  ...                           13.0
# 2       7150.0     0.0     2.0  ...                         1301.0
# 3          NaN     NaN     NaN  ...                            NaN
# 4          NaN     NaN     NaN  ...                            NaN
#
#    HYPOTHENUS_FREQ_AND_REGULARITY  MEAN_PRICE_TOP_PACK  \
# 0                          1789.0               1000.0
# 1                          1690.0                300.0
# 2                          3925.0                150.0
# 3                             NaN                  NaN
# 4                             NaN                  NaN
#
#    MENSUAL_BY_MEAN_PRICE_TOP_PACK TENURE_REGION  \
# 0                        5.000000       K_THIES
# 1                        1.086667      I_UNKNOW
# 2                       22.666667       K_DAKAR
# 3                             NaN      K_UNKNOW
# 4                             NaN      K_UNKNOW
#
#                  REGION_TOP_PACK            TOP_PACK_TENURE  \
# 0  THIES_On-net 1000F=10MilF;10d  On-net 1000F=10MilF;10d_K
# 1    UNKNOW_Data: 100 F=40MB,24H     Data: 100 F=40MB,24H_I
# 2     DAKAR_Data: 100 F=40MB,24H     Data: 100 F=40MB,24H_K
# 3                  UNKNOW_UNKNOW                   UNKNOW_K
# 4                  UNKNOW_UNKNOW                   UNKNOW_K
#
#             TENURE_REGION_TOP_PACK  TENURE_Kfold_Target_Enc  \
# 0  K_THIES_On-net 1000F=10MilF;10d                 0.183263
# 1    I_UNKNOW_Data: 100 F=40MB,24H                 0.267591
# 2     K_DAKAR_Data: 100 F=40MB,24H                 0.183263
# 3                  K_UNKNOW_UNKNOW                 0.183263
# 4                  K_UNKNOW_UNKNOW                 0.183263
#
#    REGION_Kfold_Target_Enc
# 0                 0.016845
# 1                 0.448232
# 2                 0.019122
# 3                 0.448232
# 4                 0.448232
#
# [5 rows x 31 columns]

# %%
train_transformed=full_pipeline.fit_transform(train_prepared)

# %%
test_prepared.dtypes
# Out:
# REGION                                     category
# TENURE                                     category
# MONTANT                                     float64
# FREQUENCE_RECH                              float64
# REVENUE                                     float64
# ARPU_SEGMENT                                float64
# FREQUENCE                                   float64
# DATA_VOLUME                                 float64
# ON_NET                                      float64
# ORANGE                                      float64
# TIGO                                        float64
# ZONE1                                       float64
# ZONE2                                       float64
# REGULARITY                                    int64
# TOP_PACK                                   category
# FREQ_TOP_PACK                               float64
# FREQUENCE_BY_FREQUENCE_RECH                 float64
# sum_extra                                   float64
# RATIO_ON_NET_BY_EXTRA_NET                   float64
# RATIO_ON_NET_BY_ORANGE                      float64
# RATIO_ON_NET_BY_TIGO                        float64
# HYPOTHENUS_FREQ_AND_FREQ_RECH               float64
# HYPOTHENUS_FREQ_AND_REGULARITY              float64
# MEAN_PRICE_TOP_PACK                         float64
# MENSUAL_BY_MEAN_PRICE_TOP_PACK              float64
# TENURE_REGION                              category
# REGION_TOP_PACK                            category
# TOP_PACK_TENURE                            category
# TENURE_REGION_TOP_PACK                     category
# TENURE_Kfold_Target_Enc                      object
# REGION_Kfold_Target_Enc                      object
# TOP_PACK_Kfold_Target_Enc                    object
# TENURE_REGION_Kfold_Target_Enc               object
# REGION_TOP_PACK_Kfold_Target_Enc             object
# TOP_PACK_TENURE_Kfold_Target_Enc             object
# TENURE_REGION_TOP_PACK_Kfold_Target_Enc      object
# dtype: object

# %%
test_prepared

# %%
test_transformed=full_pipeline.fit_transform(test_prepared)

# %%
test_prepared.columns,train_prepared.columns

# %% [markdown]
# # Dimensuality reduction, feature  extraction

# %%
X_ALL=train_prepared.copy()
X_ALL.shape
X_train_test=X_ALL.append(test_prepared)
X_train_test.shape
# Out:
# (880127, 29)

# %%
#X_train_test.iloc[999999],train_prepared.iloc[999999]

# %%
train_transformed
# Out:
# <500000x4286 sparse matrix of type '<class 'numpy.float64'>'
# 	with 14500000 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import SparsePCA
n_components=5
alpha=0.0001
random_state=2018
n_jobs=-1
#sparse_pca=SparsePCA(n_components=5,alpha=alpha,random_state=random_state,n_jobs=n_jobs)
#sparse_pca.fit(train_transformed)
#X_train_sparsePCA=np.concatenate([train_transformed,test_transformed])

# %%
train_prepared.dtypes
# Out:
# REGION                            category
# TENURE                            category
# MONTANT                            float64
# FREQUENCE_RECH                     float64
# REVENUE                            float64
# ARPU_SEGMENT                       float64
# FREQUENCE                          float64
# DATA_VOLUME                        float64
# ON_NET                             float64
# ORANGE                             float64
# TIGO                               float64
# ZONE1                              float64
# ZONE2                              float64
# REGULARITY                           int64
# TOP_PACK                          category
# FREQ_TOP_PACK                      float64
# FREQUENCE_BY_FREQUENCE_RECH        float64
# sum_extra                          float64
# RATIO_ON_NET_BY_EXTRA_NET          float64
# RATIO_ON_NET_BY_ORANGE             float64
# RATIO_ON_NET_BY_TIGO               float64
# HYPOTHENUS_FREQ_AND_FREQ_RECH      float64
# HYPOTHENUS_FREQ_AND_REGULARITY     float64
# MEAN_PRICE_TOP_PACK                float64
# MENSUAL_BY_MEAN_PRICE_TOP_PACK     float64
# TENURE_REGION                     category
# REGION_TOP_PACK                   category
# TOP_PACK_TENURE                   category
# TENURE_REGION_TOP_PACK            category
# dtype: object

# %%
X_train_test_transformed=full_pipeline.fit_transform(X_train_test).toarray()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-af1a99663c01> in <module>
# ----> 1 X_train_test_transformed=full_pipeline.fit_transform(X_train_test).toarray()
#
# NameError: name 'X_train_test' is not defined

# %%
from sklearn.decomposition import PCA
#pca=PCA(n_components=2)
#pca.fit(X_train_test_transformed)

# %%
#X_train_pca=pca.transform(X_train_test_transformed[:500000])
#X_test_pca=pca.transform(X_train_test_transformed[500000:])

# %%
X_train_test_transformed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-96fb24446da3> in <module>
# ----> 1 X_train_test_transformed
#
# NameError: name 'X_train_test_transformed' is not defined

# %% [markdown]
# # Training XGboost model

# %%
# !pip3 install xgboost
# Out:
# Requirement already satisfied: xgboost in /Users/macbook/miniconda3/envs/machineLearning/lib/python3.8/site-packages (1.3.3)
# Requirement already satisfied: numpy in /Users/macbook/miniconda3/envs/machineLearning/lib/python3.8/site-packages (from xgboost) (1.19.1)
# Requirement already satisfied: scipy in /Users/macbook/miniconda3/envs/machineLearning/lib/python3.8/site-packages (from xgboost) (1.5.3)

# %%
# !brew install libomp
# Out:
# zsh:1: command not found: brew

# %%
import xgboost
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# CV model
model = xgboost.XGBClassifier(objective='logloss')
kfold = KFold(n_splits=10, random_state=7)
results = cross_val_score(model, train_transformed, train_labels, cv=kfold)
print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# /Users/macbook/miniconda3/envs/machineLearning/lib/python3.8/site-packages/sklearn/model_selection/_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# /Users/macbook/miniconda3/envs/machineLearning/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [17:16:51] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:18:21] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:19:52] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:22:09] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:23:43] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:25:13] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:26:44] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:28:16] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:29:47] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:31:17] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy: 87.94% (0.11%)

# %%
import xgboost
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# CV model
model = xgboost.XGBClassifier()
kfold = KFold(n_splits=10, random_state=7)
results = cross_val_score(model, train_transformed, train_labels, cv=kfold)
print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# [20:13:53] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:15:43] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:17:32] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:27:45] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:29:35] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:43:27] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:45:18] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:47:12] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:49:07] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:51:00] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy: 87.93% (0.09%)

# %%
import xgboost
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
param_test1 = {
 'max_depth' : range(1,10),
 'min_child_weight' : range(1,6)
}
xgb2 = xgboost.XGBClassifier(
        learning_rate =0.1, 
        n_estimators=65,
        max_depth=5,
        min_child_weight=1, 
        gamma=0, 
        subsample=0.8, 
        colsample_bytree=0.8,
        objective= 'binary:logistic',
        nthread=-1,
        scale_pos_weight=1, 
        seed=27
)

gsearch1 = GridSearchCV(
    estimator = xgb2, 
    param_grid = param_test1, scoring='neg_log_loss', n_jobs=-1, cv=5
)

gsearch1.fit(train_transformed, train_labels)
gsearch1.best_params_, gsearch1.best_score_
# Out:
# /Users/macbook/miniconda3/envs/machineLearning/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:29:51] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ({'max_depth': 7, 'min_child_weight': 5}, -0.25260559367635915)

# %%
import xgboost
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
param_test1 = {
 'max_depth' : range(1,10),
 'min_child_weight' : range(1,6)
}
xgb2 = xgboost.XGBClassifier(
        learning_rate =0.1, 
        n_estimators=65,
        max_depth=5,
        min_child_weight=1, 
        gamma=0, 
        subsample=0.8, 
        colsample_bytree=0.8,
        objective= 'binary:logistic',
        nthread=-1,
        scale_pos_weight=1, 
        seed=27
)

gsearch1 = GridSearchCV(
    estimator = xgb2, 
    param_grid = param_test1, scoring='neg_log_loss', n_jobs=-1, cv=5
)

gsearch1.fit(train_transformed, train_labels)
gsearch1.best_params_, gsearch1.best_score_

# %%
tr
